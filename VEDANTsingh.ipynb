# %%
# !pip install diffusers transformers accelerate torch --upgrade

# %%
# --- Updated Code Snippet ---

# Get text input from the user
prompt = input("✨ Please enter a description for the image: ")
negative_prompt = input("🚫 What should the image AVOID? (e.g., blurry, bad hands, ugly): ")

print("\n⏳ Generating your image... this might take a moment.")

# Generate the image, now including the negative prompt
with torch.no_grad():
    image = pipe(prompt, negative_prompt=negative_prompt).images[0]

print("✅ Image generated!")

# Display the image
display(image)
# Out:
# ✨ Please enter a description for the image: a gorilla
# 🚫 What should the image AVOID? (e.g., blurry, bad hands, ugly): blurry
#
# ⏳ Generating your image... this might take a moment.
#   0%|          | 0/50 [00:00<?, ?it/s]
# ✅ Image generated!
# <PIL.Image.Image image mode=RGB size=512x512>
